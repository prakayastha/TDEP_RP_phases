# %%
import matplotlib.pyplot as plt

# %%
temperature = [150,200,300]
RP_phase = [-84615.36702394855,-84615.38034981306,-84615.41460000818]

# %%
plt.plot(temperature,RP_phase,"-o")
plt.ylabel("Anharmonicity Measure")
plt.xlabel("Temperature (K)")
# Out:
# Text(0.5, 0, 'Temperature (K)')
